# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# # Init

# %%
numOfCities = 12
cities = np.random.uniform(low=-15.0, high=15.0, size=(numOfCities, 2))
pop_per_gen = 50
num_selected_pool = 40
np.random.shuffle(np.arange(numOfCities))
new_pop = np.zeros((pop_per_gen,numOfCities))
arr = np.arange(numOfCities)
for i in range(pop_per_gen):
    np.random.shuffle(arr)
    new_pop[i] = arr

# %% [markdown]
# # Functions

# %%
def cal_fitness(pop):
    fitness_pop = []
    for i in range(pop.shape[0]):
        fitness = 0
        for j in range(pop.shape[1]):
            if(j == 0):
                continue
            fitness += np.linalg.norm(cities[int(pop[i,j])]-cities[int(pop[i,j-1])])
        fitness_pop.append(fitness)
    return fitness_pop

def select_pool(pop, fitness, size):
    best_pop_creature = pop[np.argmin(fitness)]
    fitness = np.abs(fitness - np.max(fitness))
    probs = fitness / np.sum(fitness)
    selected_pool_idx = np.random.choice(np.arange(pop.shape[0]), size=size, replace=False, p=probs)
    selected_pool = pop[selected_pool_idx, :]
    selected_pool[0] = best_pop_creature
    return selected_pool

def mutate(selected_pool, size):
    mutated_pool = np.zeros((size, numOfCities))
    for i in range(size):
        creature = selected_pool[randint(0, num_selected_pool-1), :]
        random_idx = randint(1, numOfCities-1)
        creature[random_idx-1], creature[random_idx] = creature[random_idx], creature[random_idx-1]
        mutated_pool[i] = creature
    return mutated_pool

# %% [markdown]
# # Run

# %%
num_generations = 1000
best_fit = 1e9
best_creature = []
for generation in range(num_generations):
    print("Generation: ", generation+1)
    fitness = cal_fitness(new_pop)
    if(np.min(fitness) < best_fit):
        best_fit = np.min(fitness)
        best_creature = new_pop[np.argmin(fitness)]
    selected_pool = select_pool(new_pop, fitness, num_selected_pool)
    selected_mutation = mutate(selected_pool, pop_per_gen - num_selected_pool)
    new_pop = np.append(selected_pool, selected_mutation, axis = 0)
    print("Gen fitness: ", np.min(fitness))
    print("Gen creature: ", new_pop[np.argmin(fitness)])
print(best_fit)
print(best_creature)
# Out:
# Generation:  1
# Gen fitness:  121.8284403385676
# Gen creature:  [ 6. 11.  0.  4.  3. 10.  8.  5.  7.  1.  2.  9.]
# Generation:  2
# Gen fitness:  121.8284403385676
# Gen creature:  [ 8.  3.  6.  2.  1.  5.  4. 11.  9. 10.  0.  7.]
# Generation:  3
# Gen fitness:  121.8284403385676
# Gen creature:  [ 8.  3.  2.  6.  1.  5. 11.  4.  9. 10.  0.  7.]
# Generation:  4
# Gen fitness:  120.77777946597142
# Gen creature:  [ 5.  6.  3.  7. 11.  2.  0.  9.  4.  8. 10.  1.]
# Generation:  5
# Gen fitness:  118.51578526176813
# Gen creature:  [ 3.  8.  6.  2.  1.  5. 11.  4.  9. 10.  0.  7.]
# Generation:  6
# Gen fitness:  118.51578526176813
# Gen creature:  [ 4.  5.  0.  1. 10.  9. 11.  7.  2.  6.  8.  3.]
# Generation:  7
# Gen fitness:  118.51578526176813
# Gen creature:  [ 4.  5.  0.  1. 10.  9. 11.  7.  2.  6.  8.  3.]
# Generation:  8
# Gen fitness:  118.51578526176813
# Gen creature:  [ 4.  5.  0.  1. 10.  9. 11.  7.  2.  6.  8.  3.]
# Generation:  9
# ...

# %%
plt.plot(cities[:,0], cities[:,1], 'bo')
for i in range(numOfCities):
    if(i == 0):
        continue
    city_idx_prev = int(best_creature[i-1])
    city_idx = int(best_creature[i])
    
    plt.plot(cities[(city_idx_prev,city_idx),0], cities[(city_idx_prev,city_idx),1], 'r-')
print(cities)
# Out:
# [[  9.76197246   3.12554272]
#  [ -2.22362903  -6.19200264]
#  [-12.78962283   2.13114891]
#  [ -2.63788478   5.30722539]
#  [  6.5761656   -7.76892275]
#  [  6.41388812  -5.43946944]
#  [-11.51584284   0.88587251]
#  [  5.50080562   9.65352143]
#  [  0.29010004  -8.68746928]
#  [ -7.6458516   12.61518978]
#  [-14.77148603   6.69271123]
#  [  3.06266981  10.50483761]]

# %%
[[ 12.29938705 -12.89873278]
 [ 14.01946131 -14.59277441]
 [  0.0994163   11.51887938]
 [ 14.22977469   0.28238644]
 [ 10.46995541 -14.56734543]
 [-10.55424319   9.92377738]]
# Out:
#   File "<ipython-input-259-1d0aa95be9a6>", line 3
#     [  0.0994163   11.51887938]
#                              ^
# SyntaxError: invalid syntax
