# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from random import randint

# %%
POPULATION_SIZE = None
INDIVIDUAL_LENGTH = None
CROSSOVER_RATE = None
MUTATION_RATE = None

generation_count = None
population = None
fitness_values = None
probs = None
best_value = None
best_individual = None
cities = None
cost_matrix = None

# %%
def init():
    global POPULATION_SIZE, INDIVIDUAL_LENGTH, CROSSOVER_RATE, MUTATION_RATE, generation_count, population, fitness_values, best_value, best_individual, cities, cost_matrix
    POPULATION_SIZE = 30
    INDIVIDUAL_LENGTH = 280
    CROSSOVER_RATE = 0.9
    MUTATION_RATE = 0.01
    
    generation_count = 200
    population = np.zeros((POPULATION_SIZE, INDIVIDUAL_LENGTH)).astype(int)
    file = open("data/a280.tsp", "r")
#     cities = np.zeros((INDIVIDUAL_LENGTH,2))
    cities = []
    lines_skip = 6
    best_value = 1e9
    for i in file.read().split('\n')[lines_skip:lines_skip + INDIVIDUAL_LENGTH]:
        cities.append([float(i.split()[1]), float(i.split()[2])])
    cost_matrix = np.zeros((INDIVIDUAL_LENGTH, INDIVIDUAL_LENGTH))
    for i in range(INDIVIDUAL_LENGTH):
        for j in range(INDIVIDUAL_LENGTH):
            cost_matrix[i,j] = np.linalg.norm(np.array(cities[i]) - np.array(cities[j]))

# %%
def init_population():
    global POPULATION_SIZE, INDIVIDUAL_LENGTH, population
    individual = np.arange(INDIVIDUAL_LENGTH)
    np.random.shuffle(individual)

    for i in range(POPULATION_SIZE):
        np.random.shuffle(individual)
        idx = np.argmin(individual)
        population[i] = individual

# %%
def evaluate():
    global population, INDIVIDUAL_LENGTH, POPULATION_SIZE, fitness_values, probs, best_value, best_individual
    fitness_values = []
    probs = []
    for i in range(population.shape[0]):
        fitness = 0
        for j in range(population.shape[1]):
            if(j == 0):
                continue
            fitness += cost_matrix[int(population[i,j]), int(population[i,j-1])]
        fitness += cost_matrix[int(population[i,0]), int(population[i,INDIVIDUAL_LENGTH-1])]
        fitness_values.append(fitness)
    
    if(best_value > np.min(fitness_values)):
        best_value = np.min(fitness_values)
        best_individual = population[np.argmin(fitness_values)]
    
    probs = fitness_values / np.sum(fitness_values)
    probs = [[value,key] for (value,key) in sorted([(value,key) for (key,value) in enumerate(probs)])]
    for i in range(population.shape[0]):
        if(i==0):
            continue
        probs[i][0] += probs[i-1][0]
    return None

# %%
#sequential constructive crossover
def SCX(P1,P2,val):
    global INDIVIDUAL_LENGTH
    offspring = []
    offspring.append(0)
    
    mask = np.ones(INDIVIDUAL_LENGTH).astype(int)
    mask[0] = 0
    
    next_dp1 = np.zeros(INDIVIDUAL_LENGTH).astype(int)
    next_dp2 = np.zeros(INDIVIDUAL_LENGTH).astype(int)
    
    curr = (np.where(P1 == 0)[0][0] + val)%INDIVIDUAL_LENGTH
    next_dp1[0] = P1[curr]
    
    while(P1[curr] != 0):
        idx = np.where(P1 == P1[curr])[0][0]
        idx = (idx+val)%INDIVIDUAL_LENGTH
        next_dp1[P1[curr]] = P1[idx]
        curr = idx
        
    curr = (np.where(P2 == 0)[0][0] + val)%INDIVIDUAL_LENGTH
    next_dp2[0] = P2[curr]
    while(P2[curr] != 0):
        idx = np.where(P2 == P2[curr])[0][0]
        idx = (idx+val)%INDIVIDUAL_LENGTH
        next_dp2[P2[curr]] = P2[idx]
        curr = idx

    while(len(offspring) < INDIVIDUAL_LENGTH):
        last_node = offspring[-1]
        dp1 = last_node
        dp2 = last_node 
        while(mask[int(dp1)] == 0):
            dp1 = next_dp1[int(dp1)]
        while(mask[int(dp2)] == 0):
            dp2 = next_dp2[int(dp2)]
        if(cost_matrix[int(last_node), int(dp1)] <= cost_matrix[int(last_node), int(dp2)]):
            offspring.append(int(dp1))
            mask[int(dp1)] = 0
        else:
            offspring.append(dp2)
            mask[int(dp2)] = 0
    return offspring

# %%
#partially mapped crossover
def PMX(P1,P2):
    global INDIVIDUAL_LENGTH
    offspring1 = P1.copy()
    offspring2 = P2.copy()
    
    next_dp1 = np.zeros(INDIVIDUAL_LENGTH).astype(int)
    next_dp2 = np.zeros(INDIVIDUAL_LENGTH).astype(int)
    
    for idx, val in enumerate(P1):
        next_dp1[int(val)] = idx
    for idx, val in enumerate(P2):
        next_dp2[int(val)] = idx
    
    m = randint(0, INDIVIDUAL_LENGTH)
    
    for index in range(m, int(m +INDIVIDUAL_LENGTH/2)):
        i = index%INDIVIDUAL_LENGTH
        idx = next_dp1[P2[i]]
        offspring1[i], offspring1[idx] = offspring1[idx], offspring1[i]
    
    for index in range(m, int(m +INDIVIDUAL_LENGTH/2)):
        i = index%INDIVIDUAL_LENGTH
        idx = next_dp2[P1[i]]
        offspring2[i], offspring2[idx] = offspring2[idx], offspring2[i]
    
    return offspring1, offspring2

# %%
def mutate(individual, prob):
    global INDIVIDUAL_LENGTH, population
    if(prob >= 0.5):
        m = INDIVIDUAL_LENGTH
        n = 0
        while(n < m or m ==0):
            m = randint(1, INDIVIDUAL_LENGTH)
            n = randint(1, INDIVIDUAL_LENGTH)
        individual[m:n] = individual[m:n][::-1]
    else:
        m = INDIVIDUAL_LENGTH
        n = 0
        while(n <= m or m ==0):
            m = randint(1, INDIVIDUAL_LENGTH)
            n = randint(1, INDIVIDUAL_LENGTH)
        clone = individual.copy()
        individual[1:(n-m+1)], individual[(n-m+1):n] = clone[m:n], clone[1:m]
    return individual

# %%
def mutation():
    global population, MUTATION_RATE, POPULATION_SIZE
    for i in range(POPULATION_SIZE):
        if(i==0):
            continue
        if(np.random.sample() < MUTATION_RATE):
            population[i] = mutate(population[i].copy(),np.random.sample())

# %%
def crossover():
    global population, POPULATION_SIZE, CROSSOVER_RATE
    crossover_list = []
    for i in range(POPULATION_SIZE):
        if(np.random.sample() < CROSSOVER_RATE):
            crossover_list.append(i)
    np.random.shuffle(crossover_list)
    for i in range(0, len(crossover_list)-1, 2):
        idx1 = crossover_list[i]
        idx2 = crossover_list[i+1]
        population[idx1], population[idx2] = SCX(population[idx1].copy(), population[idx2].copy(), 1), SCX(population[idx1].copy(), population[idx2].copy(), -1)
#         population[idx1], population[idx2] = PMX(population[idx1].copy(), population[idx2].copy())

# %%
def select(prob):
    for i in range(POPULATION_SIZE):
        if(probs[i][0] >= prob):
            return population[probs[i][1]]
    return population[probs[POPULATION_SIZE-1][1]]

# %%
def selection():
    global population, probs, POPULATION_SIZE
    parents = np.zeros((POPULATION_SIZE, INDIVIDUAL_LENGTH)).astype(int)
    init_count = 7
    parents[0:init_count] = population[[key for [value,key] in probs[POPULATION_SIZE-init_count:POPULATION_SIZE]]]
    for i in range(init_count, POPULATION_SIZE):
        parents[i] = select(np.random.sample())
    population = parents

# %%
init()
init_population()

# %%
generation_count = 500
for i in range(generation_count):
    print("Generation", i+1)
    evaluate()
    print("Best value generation", np.min(fitness_values))
    print("Best value", best_value)
    selection()
    crossover()
    mutation()
# Out:
# Generation 1
# Best value generation 31782.498911794843
# Best value 31782.498911794843
# Generation 2
# Best value generation 23630.92411092234
# Best value 23630.92411092234
# Generation 3
# Best value generation 19767.79775685614
# Best value 19767.79775685614
# Generation 4
# Best value generation 17689.455281470015
# Best value 17689.455281470015
# Generation 5
# Best value generation 14931.10787939053
# Best value 14931.10787939053
# Generation 6
# Best value generation 13598.02512082901
# Best value 13598.02512082901
# Generation 7
# Best value generation 13356.15868800485
# Best value 13356.15868800485
# Generation 8
# Best value generation 12245.356353999072
# Best value 12245.356353999072
# Generation 9
# Best value generation 11779.003624332114
# Best value 11779.003624332114
# Generation 10
# Best value generation 9943.262560900743
# Best value 9943.262560900743
# Generation 11
# Best value generation 10243.782382850812
# Best value 9943.262560900743
# Generation 12
# Best value generation 9414.238049860158
# Best value 9414.238049860158
# Generation 13
# Best value generation 8422.569376178548
# Best value 8422.569376178548
# Generation 14
# Best value generation 8096.995266347228
# Best value 8096.995266347228
# Generation 15
# Best value generation 7917.1581988188955
# Best value 7917.1581988188955
# Generation 16
# Best value generation 7597.412172094146
# Best value 7597.412172094146
# Generation 17
# Best value generation 6816.5107282288045
# Best value 6816.5107282288045
# Generation 18
# Best value generation 6937.181644910352
# Best value 6816.5107282288045
# Generation 19
# Best value generation 6277.343774621232
# Best value 6277.343774621232
# Generation 20
# Best value generation 6107.477809655754
# Best value 6107.477809655754
# Generation 21
# Best value generation 5976.344677357563
# Best value 5976.344677357563
# Generation 22
# Best value generation 5755.8511555799205
# Best value 5755.8511555799205
# Generation 23
# Best value generation 5511.118321154925
# Best value 5511.118321154925
# Generation 24
# Best value generation 5479.983632905084
# Best value 5479.983632905084
# Generation 25
# Best value generation 5194.924521987288
# Best value 5194.924521987288
# Generation 26
# Best value generation 4882.921700511042
# Best value 4882.921700511042
# Generation 27
# Best value generation 5077.523705016926
# Best value 4882.921700511042
# Generation 28
# Best value generation 4983.044775806021
# Best value 4882.921700511042
# Generation 29
# Best value generation 4606.812076435559
# Best value 4606.812076435559
# Generation 30
# Best value generation 4649.471257454457
# Best value 4606.812076435559
# Generation 31
# Best value generation 4664.700094409176
# Best value 4606.812076435559
# Generation 32
# Best value generation 4642.554767920892
# Best value 4606.812076435559
# Generation 33
# Best value generation 4603.639402489598
# Best value 4603.639402489598
# Generation 34
# Best value generation 4358.0252666904435
# Best value 4358.0252666904435
# Generation 35
# Best value generation 4231.138279252624
# Best value 4231.138279252624
# Generation 36
# Best value generation 4490.64249815733
# Best value 4231.138279252624
# Generation 37
# Best value generation 4606.770026433782
# Best value 4231.138279252624
# Generation 38
# Best value generation 4168.500647467655
# Best value 4168.500647467655
# Generation 39
# Best value generation 3898.756849867498
# Best value 3898.756849867498
# Generation 40
# Best value generation 4372.450566087305
# Best value 3898.756849867498
# Generation 41
# Best value generation 4153.630008576771
# Best value 3898.756849867498
# Generation 42
# Best value generation 3996.8955907571185
# Best value 3898.756849867498
# Generation 43
# Best value generation 4057.3628530192964
# Best value 3898.756849867498
# Generation 44
# Best value generation 3804.7576081234806
# Best value 3804.7576081234806
# Generation 45
# Best value generation 4167.508557400371
# Best value 3804.7576081234806
# Generation 46
# Best value generation 4031.681573954241
# Best value 3804.7576081234806
# Generation 47
# Best value generation 3898.5791612614817
# Best value 3804.7576081234806
# Generation 48
# Best value generation 4039.948449599381
# Best value 3804.7576081234806
# Generation 49
# Best value generation 3841.9269131217693
# Best value 3804.7576081234806
# Generation 50
# Best value generation 4104.5842836712445
# Best value 3804.7576081234806
# Generation 51
# Best value generation 3814.8546994457542
# Best value 3804.7576081234806
# Generation 52
# Best value generation 3814.8546994457542
# Best value 3804.7576081234806
# Generation 53
# Best value generation 3851.3022634879258
# Best value 3804.7576081234806
# Generation 54
# Best value generation 3977.6447255087887
# Best value 3804.7576081234806
# Generation 55
# Best value generation 3883.353102113095
# Best value 3804.7576081234806
# Generation 56
# Best value generation 3840.4574461275706
# Best value 3804.7576081234806
# Generation 57
# Best value generation 3881.208279011894
# Best value 3804.7576081234806
# Generation 58
# Best value generation 3891.4236793390573
# Best value 3804.7576081234806
# Generation 59
# Best value generation 3935.563957156636
# Best value 3804.7576081234806
# Generation 60
# Best value generation 3839.7874780959064
# Best value 3804.7576081234806
# Generation 61
# Best value generation 3827.8556910256825
# Best value 3804.7576081234806
# Generation 62
# Best value generation 3778.1916916068485
# Best value 3778.1916916068485
# Generation 63
# Best value generation 3619.625854086165
# Best value 3619.625854086165
# Generation 64
# Best value generation 3644.707630450313
# Best value 3619.625854086165
# Generation 65
# Best value generation 3579.779649331161
# Best value 3579.779649331161
# Generation 66
# Best value generation 3639.603301083126
# Best value 3579.779649331161
# Generation 67
# Best value generation 3702.8799640161824
# Best value 3579.779649331161
# Generation 68
# Best value generation 3735.0356673071024
# Best value 3579.779649331161
# Generation 69
# Best value generation 3629.8860423553933
# Best value 3579.779649331161
# Generation 70
# Best value generation 3747.996404106173
# Best value 3579.779649331161
# Generation 71
# Best value generation 3541.949714520483
# Best value 3541.949714520483
# Generation 72
# Best value generation 3631.973585862939
# Best value 3541.949714520483
# Generation 73
# Best value generation 3644.4723048432934
# Best value 3541.949714520483
# Generation 74
# Best value generation 3641.1365284292297
# Best value 3541.949714520483
# Generation 75
# Best value generation 3641.1365284292297
# Best value 3541.949714520483
# Generation 76
# Best value generation 3582.2237634668913
# Best value 3541.949714520483
# Generation 77
# Best value generation 3663.675831324359
# Best value 3541.949714520483
# Generation 78
# Best value generation 3539.16697889514
# Best value 3539.16697889514
# Generation 79
# Best value generation 3570.341225494362
# Best value 3539.16697889514
# Generation 80
# Best value generation 3653.725613755719
# Best value 3539.16697889514
# Generation 81
# Best value generation 3579.9841296379877
# Best value 3539.16697889514
# Generation 82
# Best value generation 3704.835297089976
# Best value 3539.16697889514
# Generation 83
# Best value generation 3634.2387088865166
# Best value 3539.16697889514
# Generation 84
# Best value generation 3574.1580741346233
# Best value 3539.16697889514
# Generation 85
# Best value generation 3612.007825061397
# Best value 3539.16697889514
# Generation 86
# Best value generation 3608.9655142773195
# Best value 3539.16697889514
# Generation 87
# Best value generation 3631.686114540211
# Best value 3539.16697889514
# Generation 88
# Best value generation 3709.343220100983
# Best value 3539.16697889514
# Generation 89
# Best value generation 3806.535568355708
# Best value 3539.16697889514
# Generation 90
# Best value generation 3838.660725546472
# Best value 3539.16697889514
# Generation 91
# Best value generation 3523.923419256073
# Best value 3523.923419256073
# Generation 92
# Best value generation 3624.00642190444
# Best value 3523.923419256073
# Generation 93
# Best value generation 3594.4643684567645
# Best value 3523.923419256073
# Generation 94
# Best value generation 3717.7296532985156
# Best value 3523.923419256073
# Generation 95
# Best value generation 3596.738504763355
# Best value 3523.923419256073
# Generation 96
# Best value generation 3536.5486889944136
# Best value 3523.923419256073
# Generation 97
# Best value generation 3578.5931886944145
# Best value 3523.923419256073
# Generation 98
# Best value generation 3584.395526396602
# Best value 3523.923419256073
# Generation 99
# Best value generation 3622.479214791082
# Best value 3523.923419256073
# Generation 100
# Best value generation 3648.8932748697825
# Best value 3523.923419256073
# Generation 101
# Best value generation 3650.1008657875836
# Best value 3523.923419256073
# Generation 102
# Best value generation 3350.9434693097674
# Best value 3350.9434693097674
# Generation 103
# Best value generation 3507.2796413703813
# Best value 3350.9434693097674
# Generation 104
# Best value generation 3658.833075752106
# Best value 3350.9434693097674
# Generation 105
# Best value generation 3468.7606047949453
# Best value 3350.9434693097674
# Generation 106
# Best value generation 3739.9698129301487
# Best value 3350.9434693097674
# Generation 107
# Best value generation 3581.573364326891
# Best value 3350.9434693097674
# Generation 108
# Best value generation 3549.4357651068713
# Best value 3350.9434693097674
# Generation 109
# Best value generation 3652.7646199256064
# Best value 3350.9434693097674
# Generation 110
# Best value generation 3652.7646199256064
# Best value 3350.9434693097674
# Generation 111
# Best value generation 3720.088040190372
# Best value 3350.9434693097674
# Generation 112
# Best value generation 3814.041616169388
# Best value 3350.9434693097674
# Generation 113
# Best value generation 3442.6596246854156
# Best value 3350.9434693097674
# Generation 114
# Best value generation 3641.248856323461
# Best value 3350.9434693097674
# Generation 115
# Best value generation 3563.3876222901695
# Best value 3350.9434693097674
# Generation 116
# Best value generation 3707.6615480246714
# Best value 3350.9434693097674
# Generation 117
# Best value generation 3572.054333278381
# Best value 3350.9434693097674
# Generation 118
# Best value generation 3556.510220125472
# Best value 3350.9434693097674
# Generation 119
# Best value generation 3618.795278939714
# Best value 3350.9434693097674
# Generation 120
# Best value generation 3629.3985912549897
# Best value 3350.9434693097674
# Generation 121
# Best value generation 3761.2327001638873
# Best value 3350.9434693097674
# Generation 122
# Best value generation 3833.4791582349794
# Best value 3350.9434693097674
# Generation 123
# Best value generation 3693.908218115993
# Best value 3350.9434693097674
# Generation 124
# Best value generation 3471.3686261469697
# Best value 3350.9434693097674

# %%
print(best_value)
plot_cities = np.array(cities)
plt.plot(plot_cities[:,0], plot_cities[:,1], 'bo')
for i in range(INDIVIDUAL_LENGTH):
    if(i == 0):
        city_idx_prev = int(best_individual[0])
        city_idx = int(best_individual[INDIVIDUAL_LENGTH-1])
        plt.plot(plot_cities[(city_idx_prev,city_idx),0], plot_cities[(city_idx_prev,city_idx),1], 'r-')
        continue
    city_idx_prev = int(best_individual[i-1])
    city_idx = int(best_individual[i])
    plt.plot(plot_cities[(city_idx_prev,city_idx),0], plot_cities[(city_idx_prev,city_idx),1], 'r-')
    
plt.show()
